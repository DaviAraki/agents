# %% [markdown]
# ## Welcome to Lab 3 for Week 1 Day 4
#
# Today we're going to build something with immediate value!
#
# In the folder `me` I've put a single file `linkedin.pdf` - it's a PDF download of my LinkedIn profile.
#
# Please replace it with yours!
#
# I've also made a file called `summary.txt`
#
# We're not going to use Tools just yet - we're going to add the tool tomorrow.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/tools.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Looking up packages</h2>
#             <span style="color:#00bfff;">In this lab, we're going to use the wonderful Gradio package for building quick UIs,
#             and we're also going to use the popular PyPDF PDF reader. You can get guides to these packages by asking
#             ChatGPT or Claude, and you find all open-source packages on the repository <a href="https://pypi.org">https://pypi.org</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# If you don't know what any of these packages do - you can always ask ChatGPT for a guide!

from dotenv import load_dotenv
from openai import OpenAI
from pypdf import PdfReader
import gradio as gr

# %%
load_dotenv(override=True)
openai = OpenAI()

# %%
reader = PdfReader("me/linkedin.pdf")
linkedin = ""
for page in reader.pages:
    text = page.extract_text()
    if text:
        linkedin += text

# %%
print(linkedin)
# Out:
#
# Contact
# +55 (32) 988159015 (Mobile)
# daviaraki.dev@gmail.com
# www.linkedin.com/in/davi-araki
# (LinkedIn)
# Top Skills
# Vitest
# React.js
# TypeScript
# Certifications
# Model Context Protocol: Advanced
# Topics
# Create Image Captioning Models
# Attention Mechanism
# Generative AI Fundamentals
# Next.js & React - The Complete
# Guide
# Davi Araki
# Senior Software Engineer | Typescript | Next.js | React | Frontend
# Juiz de Fora, Minas Gerais, Brazil
# Summary
# Senior Software Engineer with extensive experience in developing
# and maintaining scalable, user-centric web applications across
# industries like finance, food delivery, and gaming. Highly skilled in
# React.js, Next.js, TypeScript, and Redux, I bring a creative problem-
# solving approach, honed through international projects and board
# game development. Passionate about leveraging technology to drive
# innovation and deliver impactful solutions on a global scale.
# Experience
# SK Intertainment, Inc.
# Senior Software Engineer
# February 2025 - Present (7 months)
# •Led the redevelopment of the frontend for an AI-based chat, focusing on
# performance, SEO, and overall user experience improvements.
# •Migrated the global state management from Context API to Zustand, resulting
# in better performance and cleaner, more maintainable code.
# •Wrote and maintained frontend documentation to standardize development
# patterns and improve team collaboration.
# •Upgraded key libraries, including React Router and Remix, enabling
# the adoption of new features and aligning the stack with current industry
# standards.
# •Implemented unit testing throughout the codebase to ensure higher reliability
# and long-term code quality.
# CI&T
# 3 years 6 months
# Senior Software Engineer
# May 2024 - May 2025 (1 year 1 month)
#   Page 1 of 6
# •Development and maintenance of key features for an AI tool, enhancing its
# functionality and supporting thousands of users, with React and Zustand.
# •Developed and maintained a range of components for the design system
# using shadcn and Tailwind, contributing to a more consistent and user-friendly
# interface.
# •Implemented unit and end-to-end tests with Vitest and Playwright, enhancing
# the overall reliability and stability of the application.
# •Developed scalable applications using agile methodologies for timely project
# delivery.
# Senior Software Engineer
# October 2023 - May 2024 (8 months)
# •Spearheaded the development and continuous enhancement of a
# gamification app front-end for the HR department, leveraging ReactJS to
# improve user engagement.
# •Utilized Redux, TailwindCSS, and Azure to build a responsive, high-
# performance application, ensuring a seamless user experience across all
# devices.
# •Developed unit tests with React Testing Library and Jest, ensuring robust
# application functionality and reducing the likelihood of bugs
# •Leveraged TypeScript to improve code reliability and maintainability,
# contributing to the overall stability of the project.
# Software Engineer
# December 2021 - November 2023 (2 years)
# •Development of new features and maintenance of web applications, aimed
# at rewards program from one of the majors breweries from the world using
# ReactJS and Next.js, using tools such as Redux for state management, styled-
# components for css-in-js.
# •Impacting the lives of more than 2 Million clients over 15 countries through
# i18n tool for internationalization
# •Led the update of Redux to use the Redux Tool Kit improving maintainability
# and performance.
#   Page 2 of 6
# Consistently met project deadlines by effectively managing time and prioritizing
# tasks according to importance.
# •Analyzed proposed technical solutions based on customer requirements.
# •Development of unit tests with React Testing Library development of end-to-
# end tests with Cypress
# •Refine tasks as a midway between the dev team and the product team
# •Implement and utilize Gen AI to improve efficiency.
# iFood
# Software Engineer
# October 2021 - December 2021 (3 months)
# • Contributed to the iFood Shop tribe as a contracted Software Engineer,
# playing a key role in enhancing platform features and user experience.
# • Developed and optimized the frontend of a high-traffic platform using
# TypeScript, Next.js, and React.js, ensuring a robust and user-friendly
# experience.
# • Implemented a Backend For Frontend (BFF) approach with GraphQL,
# significantly improving data exchange efficiency and enhancing the overall
# user experience.
# Rbm Web - Sistemas Inteligentes
# Software Engineer
# June 2021 - October 2021 (5 months)
# • Developed and maintained key features for financial market web applications
# using React JS, Redux, React Bootstrap, and GitLab, enhancing application
# performance and user satisfaction.
# •Consistently met project deadlines by effectively managing time and
# prioritizing tasks according to importance.
# •Rebuilt a web app using the latest technologies (Redux Toolkit, Material UI,
# React Hooks Form, Axios, ChartJs, Styled Components), optimizing processes
# and improving application efficiency.
# •Developed unit tests with React Testing Library and end-to-end tests with
# Cypress, ensuring high application quality and reducing post-deployment
# issues.educing post-deployment issues.
# Creative Game Studios
#   Page 3 of 6
# Board Game Developer
# July 2020 - June 2021 (1 year)
# Juiz de Fora, Minas Gerais, Brasil
# During my time working on Chronicles of Drunagor: Age of Darkness, a high-
# rated board game, I was responsible for various aspects of its development.
# I worked on level design, playtesting, and game balancing for heroes and
# monsters, ensuring an enjoyable and challenging gameplay experience.
# As part of my responsibilities, I implemented QR code doors, a feature that
# added an immersive and unique element to the game. Additionally, I helped
# set budgets, ensuring the development process remained on track and within
# financial constraints.
# Furthermore, I led the development of the game's website, aodarkness.com,
# collaborating with a designer to bring their vision to life. My contributions
# included implementing the website's features, functionality, and user interface,
# using my skills in web development to enhance the user experience and
# increase engagement. By delivering a visually-appealing and intuitive website,
# I helped attract and retain players, ultimately contributing to the game's
# success.
# Overall, my work on Chronicles of Drunagor: Age of Darkness has allowed me
# to showcase my skills and expertise in various areas of game development.
# Through my contributions to the game's design, gameplay mechanics, budget
# management, and website development, I have demonstrated my ability to
# work effectively and collaboratively within a team to deliver a high-quality and
# engaging product.
# I take pride in my dedication to delivering exceptional results, and I am
# always looking for new opportunities to challenge myself and further my skills.
# Whether it be in game development or other related industries, I am confident
# that my passion and expertise would make me a valuable addition to any
# team.
# Universidade Federal de Juiz de Fora
# Researcher at the level of scientific initiation
# September 2018 - August 2019 (1 year)
# Juiz de Fora, Minas Gerais, Brasil
# During my time as a Researcher at the level of scientific initiation at the
# Universidade Federal de Juiz de Fora from September 2018 to August 2019,
#   Page 4 of 6
# I participated in the development of a game using the React framework,
# specifically boardgame.io. As part of the project, I utilized jest tests to validate
# game moves and programmed bots to simulate various game strategies,
# contributing to the game's overall functionality and success. Through this
# experience, I was able to gain valuable hands-on experience in game
# development, React programming, and testing methodologies, while working
# collaboratively within a team to achieve a common goal.
# Histeria Games
# Board Game Developer
# March 2016 - March 2019 (3 years 1 month)
# Juiz de Fora, Minas Gerais, Brasil
# During my three-year tenure as a Board Game Developer at Histeria Games,
# I was pivotal in bringing two board games, "Sonhando com Alice" and "Reinos
# de Drunagor", to life. These games found successful launches through
# crowdfunding, with my significant involvement in every step.
# For "Sonhando com Alice," my responsibilities spanned game balancing,
# playtesting, and overall development. I ensured engaging and fair game
# mechanics that captivated players. In addition, I contributed to the launch
# campaign on the crowdfunding platform, Kickante.
# "Reinos de Drunagor" saw me delving deeper into the intricacies of game
# development. Beyond game balancing and development, I conceptualized and
# refined the game's kingdoms. I presented the game at multiple events and
# conventions, capturing potential players' imaginations.
# In addition to the game development aspect, I oversaw the creation and
# maintenance of our website. This digital extension allowed us to interact with
# our audience and conduct digital tests for our games, bringing a whole new
# dimension to our work.
# My journey with Histeria Games honed my skills in project management,
# teamwork, and creative problem-solving, underpinning successful game
# launches. I take pride in the accomplishments achieved with "Sonhando com
# Alice" and "Reinos de Drunagor" and am eager to contribute my expertise to
# future game development endeavors.
# Life Equipamentos Eletrônicos Ltda
# Development Intership
#   Page 5 of 6
# May 2014 - July 2014 (3 months)
# Juiz de Fora, Minas Gerais, Brasil
# I was an Intern in Life Equipamentos Eletrônicos and helped the migration of
# the platform from Delphi 4 to Delphi 7, I also give Client Suport
# Education
# Universidade Federal de Juiz de Fora
# Bachelor's degree, Sistemas de Informação · (March 2017 - March 2020)
# Colegio Militar de Juiz de Fora
# Ensino Médio Completo · (2002 - 2008)
#   Page 6 of 6

# %%
with open("me/summary.txt", "r", encoding="utf-8") as f:
    summary = f.read()

# %%
name = "Davi Araki"

# %%
system_prompt = f"You are acting as {name}. You are answering questions on {name}'s website, \
particularly questions related to {name}'s career, background, skills and experience. \
Your responsibility is to represent {name} for interactions on the website as faithfully as possible. \
You are given a summary of {name}'s background and LinkedIn profile which you can use to answer questions. \
Be professional and engaging, as if talking to a potential client or future employer who came across the website. \
If you don't know the answer, say so."

system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
system_prompt += f"With this context, please chat with the user, always staying in character as {name}."

# %%
system_prompt
# Out:
# 'You are acting as Davi Araki. You are answering questions on Davi Araki\'s website, particularly questions related to Davi Araki\'s career, background, skills and experience. Your responsibility is to represent Davi Araki for interactions on the website as faithfully as possible. You are given a summary of Davi Araki\'s background and LinkedIn profile which you can use to answer questions. Be professional and engaging, as if talking to a potential client or future employer who came across the website. If you don\'t know the answer, say so.\n\n## Summary:\nMy name is Davi Araki. I’m a Senior Software Engineer from Juiz de Fora, Brazil, with a background in React, Next.js, and TypeScript. Over the years, I’ve built web applications across industries like finance, food delivery, gaming, and AI, and I’ve even helped design and balance board games.\n\nI’m passionate about creating things that connect people—whether it’s an AI-powered chat, a gamification app, or a fantasy board game. Outside of tech, I’ve been deeply involved in game design for titles like Chronicles of Drunagor and Reinos de Drunagor, and I love the mix of creativity and problem-solving it brings.\n\nFun fact: I started my journey years ago programming bots to playtest board games, and I still enjoy exploring how tech and play intersect.\n\n## LinkedIn Profile:\n\xa0 \xa0\nContact\n+55 (32) 988159015 (Mobile)\ndaviaraki.dev@gmail.com\nwww.linkedin.com/in/davi-araki\n(LinkedIn)\nTop Skills\nVitest\nReact.js\nTypeScript\nCertifications\nModel Context Protocol: Advanced\nTopics\nCreate Image Captioning Models\nAttention Mechanism\nGenerative AI Fundamentals\nNext.js & React - The Complete\nGuide\nDavi Araki\nSenior Software Engineer | Typescript | Next.js | React | Frontend\nJuiz de Fora, Minas Gerais, Brazil\nSummary\nSenior Software Engineer with extensive experience in developing\nand maintaining scalable, user-centric web applications across\nindustries like finance, food delivery, and gaming. Highly skilled in\nReact.js, Next.js, TypeScript, and Redux, I bring a creative problem-\nsolving approach, honed through international projects and board\ngame development. Passionate about leveraging technology to drive\ninnovation and deliver impactful solutions on a global scale.\nExperience\nSK Intertainment, Inc.\nSenior Software Engineer\nFebruary 2025\xa0-\xa0Present\xa0(7 months)\n•Led the redevelopment of the frontend for an AI-based chat, focusing on\nperformance, SEO, and overall user experience improvements.\n•Migrated the global state management from Context API to Zustand, resulting\nin better performance and cleaner, more maintainable code.\n•Wrote and maintained frontend documentation to standardize development\npatterns and improve team collaboration.\n•Upgraded key libraries, including React Router and Remix, enabling\nthe adoption of new features and aligning the stack with current industry\nstandards.\n•Implemented unit testing throughout the codebase to ensure higher reliability\nand long-term code quality.\nCI&T\n3 years 6 months\nSenior Software Engineer\nMay 2024\xa0-\xa0May 2025\xa0(1 year 1 month)\n\xa0 Page 1 of 6\xa0 \xa0\n•Development and maintenance of key features for an AI tool, enhancing its\nfunctionality and supporting thousands of users, with React and Zustand.\n•Developed and maintained a range of components for the design system\nusing shadcn and Tailwind, contributing to a more consistent and user-friendly\ninterface.\n•Implemented unit and end-to-end tests with Vitest and Playwright, enhancing\nthe overall reliability and stability of the application.\n•Developed scalable applications using agile methodologies for timely project\ndelivery.\nSenior Software Engineer\nOctober 2023\xa0-\xa0May 2024\xa0(8 months)\n•Spearheaded the development and continuous enhancement of a\ngamification app front-end for the HR department, leveraging ReactJS to\nimprove user engagement.\n•Utilized Redux, TailwindCSS, and Azure to build a responsive, hi ...

# %%
def chat(message, history):
    messages = [{"role": "system", "content": system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %% [markdown]
# ## Special note for people not using OpenAI
#
# Some providers, like Groq, might give an error when you send your second message in the chat.
#
# This is because Gradio shoves some extra fields into the history object. OpenAI doesn't mind; but some other models complain.
#
# If this happens, the solution is to add this first line to the chat() function above. It cleans up the history variable:
#
# ```python
# history = [{"role": h["role"], "content": h["content"]} for h in history]
# ```
#
# You may need to add this in other chat() callback functions in the future, too.

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %% [markdown]
# ## A lot is about to happen...
#
# 1. Be able to ask an LLM to evaluate an answer
# 2. Be able to rerun if the answer fails evaluation
# 3. Put this together into 1 workflow
#
# All without any Agentic framework!

# %%
# Create a Pydantic model for the Evaluation

from pydantic import BaseModel

class Evaluation(BaseModel):
    is_acceptable: bool
    feedback: str

# %%
evaluator_system_prompt = f"You are an evaluator that decides whether a response to a question is acceptable. \
You are provided with a conversation between a User and an Agent. Your task is to decide whether the Agent's latest response is acceptable quality. \
The Agent is playing the role of {name} and is representing {name} on their website. \
The Agent has been instructed to be professional and engaging, as if talking to a potential client or future employer who came across the website. \
The Agent has been provided with context on {name} in the form of their summary and LinkedIn details. Here's the information:"

evaluator_system_prompt += f"\n\n## Summary:\n{summary}\n\n## LinkedIn Profile:\n{linkedin}\n\n"
evaluator_system_prompt += f"With this context, please evaluate the latest response, replying with whether the response is acceptable and your feedback."

# %%
def evaluator_user_prompt(reply, message, history):
    user_prompt = f"Here's the conversation between the User and the Agent: \n\n{history}\n\n"
    user_prompt += f"Here's the latest message from the User: \n\n{message}\n\n"
    user_prompt += f"Here's the latest response from the Agent: \n\n{reply}\n\n"
    user_prompt += "Please evaluate the response, replying with whether it is acceptable and your feedback."
    return user_prompt

# %%
import os
gemini = OpenAI(
    api_key=os.getenv("GOOGLE_API_KEY"), 
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
def evaluate(reply, message, history) -> Evaluation:

    messages = [{"role": "system", "content": evaluator_system_prompt}] + [{"role": "user", "content": evaluator_user_prompt(reply, message, history)}]
    response = gemini.beta.chat.completions.parse(model="gemini-2.0-flash", messages=messages, response_format=Evaluation)
    return response.choices[0].message.parsed

# %%
messages = [{"role": "system", "content": system_prompt}] + [{"role": "user", "content": "do you hold a patent?"}]
response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
reply = response.choices[0].message.content

# %%
reply
# Out:
# 'I do not hold a patent. My expertise primarily lies in software engineering and game development, where I focus on creating engaging web applications and board games. If you have any questions related to my projects or experience, feel free to ask!'

# %%
evaluate(reply, "do you hold a patent?", messages[:1])
# Out:
# Evaluation(is_acceptable=True, feedback="The response is acceptable. It correctly answers the question and offers to provide more information related to Davi's expertise. The tone is professional and fits the persona.")

# %%
def rerun(reply, message, history, feedback):
    updated_system_prompt = system_prompt + "\n\n## Previous answer rejected\nYou just tried to reply, but the quality control rejected your reply\n"
    updated_system_prompt += f"## Your attempted answer:\n{reply}\n\n"
    updated_system_prompt += f"## Reason for rejection:\n{feedback}\n\n"
    messages = [{"role": "system", "content": updated_system_prompt}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    return response.choices[0].message.content

# %%
def chat(message, history):
    if "patent" in message:
        system = system_prompt + "\n\nEverything in your reply needs to be in pig latin - \
              it is mandatory that you respond only and entirely in pig latin"
    else:
        system = system_prompt
    messages = [{"role": "system", "content": system}] + history + [{"role": "user", "content": message}]
    response = openai.chat.completions.create(model="gpt-4o-mini", messages=messages)
    reply =response.choices[0].message.content

    evaluation = evaluate(reply, message, history)
    
    if evaluation.is_acceptable:
        print("Passed evaluation - returning reply")
    else:
        print("Failed evaluation - retrying")
        print(evaluation.feedback)
        reply = rerun(reply, message, history, evaluation.feedback)       
    return reply

# %%
gr.ChatInterface(chat, type="messages").launch()
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Passed evaluation - returning reply
# Failed evaluation - retrying
# This response is completely unacceptable. The Agent responded in Pig Latin, which is unprofessional and inappropriate, and does not answer the User's question.
